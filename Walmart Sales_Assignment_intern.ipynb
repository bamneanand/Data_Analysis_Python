# %% [markdown]
# ## importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## importing Data

# %%
df = pd.read_csv(r"C:\Users\anand\Downloads\Walmart Sales.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      A  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      B     Yangon        Member    Male
# 4    373-73-7910      C     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      A  Naypyitaw        Normal    Male
# 996  303-96-2227      A   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      B     Yangon        Normal    Male
# 999  849-09-3807      C     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date   Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08
# 1    Electronic accessories       15.28         5   3/8/2019  10:29
# 2        Home and lifestyle       46.33         7   3/3/2019  13:23
# ...

# %% [markdown]
# ## Data Cleaning or Preparing the Data

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Date           1000 non-null   object
#  9   Time           1000 non-null   object
#  10  Payment        1000 non-null   object
#  11  Rating         1000 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#         Unit price     Quantity      Rating
# count  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000     6.97270
# std      26.494628     2.923431     1.71858
# min      10.080000     1.000000     4.00000
# 25%      32.875000     3.000000     5.50000
# 50%      55.230000     5.000000     7.00000
# 75%      77.935000     8.000000     8.50000
# max      99.960000    10.000000    10.00000

# %%
df.describe(include='object')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    343     340           501     501                  178
#
#             Date   Time  Payment
# count       1000   1000     1000
# unique        89    506        3
# top     2/7/2019  19:48  Ewallet
# freq          20      7      345

# %%
df.isnull().sum()
# Out:
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Date             0
# Time             0
# Payment          0
# Rating           0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Date             0
# Time             0
# Payment          0
# Rating           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Date', 'Time', 'Payment',
#        'Rating'],
#       dtype='object')

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# Invoice ID
# ['750-67-8428' '226-31-3081' '631-41-3108' '123-19-1176' '373-73-7910'
#  '699-14-3026' '355-53-5943' '315-22-5665' '665-32-9167' '692-92-5582'
#  '351-62-0822' '529-56-3974' '365-64-0515' '252-56-2699' '829-34-3910'
#  '299-46-1805' '656-95-9349' '765-26-6951' '329-62-1586' '319-50-3348'
#  '300-71-4605' '371-85-5789' '273-16-6619' '636-48-8204' '549-59-1358'
#  '227-03-5010' '649-29-6775' '189-17-4241' '145-94-9061' '848-62-7243'
#  '871-79-8483' '149-71-6266' '640-49-2076' '595-11-5460' '183-56-6882'
#  '232-16-2483' '129-29-8530' '272-65-1806' '333-73-7901' '777-82-7220'
#  '280-35-5823' '554-53-8700' '354-25-5821' '228-96-1411' '617-15-4209'
#  '132-32-9879' '370-41-7321' '727-46-3608' '669-54-1719' '574-22-5561'
#  '326-78-5178' '162-48-8011' '616-24-2851' '778-71-5554' '242-55-6721'
#  '399-46-5918' '106-35-6779' '635-40-6220' '817-48-8732' '120-06-4233'
#  '285-68-5083' '803-83-5989' '347-34-2234' '199-75-8169' '853-23-2453'
# ...

# %% [markdown]
# ## Adding Columns

# %%
df["Total"]=df['Unit price']*df['Quantity']
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      B     Yangon        Member    Male
# 4  373-73-7910      C     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment  Rating   Total
# 0      Ewallet     9.1  522.83
# 1         Cash     9.6   76.40
# 2  Credit card     7.4  324.31
# 3      Ewallet     8.4  465.76
# 4      Ewallet     5.3  604.17

# %%
df['Month'] = pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      B     Yangon        Member    Male
# 4  373-73-7910      C     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment  Rating   Total  Month
# 0      Ewallet     9.1  522.83      1
# 1         Cash     9.6   76.40      3
# 2  Credit card     7.4  324.31      3
# 3      Ewallet     8.4  465.76      1
# 4      Ewallet     5.3  604.17      2

# %%
df['Month'].unique()
# Out:
# array([1, 3, 2])

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      B     Yangon        Member    Male
# 4  373-73-7910      C     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date   Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08
# 1  Electronic accessories       15.28         5   3/8/2019  10:29
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23
# 3       Health and beauty       58.22         8  1/27/2019  20:33
# 4       Sports and travel       86.31         7   2/8/2019  10:37
#
#        Payment  Rating   Total  Month  Year
# 0      Ewallet     9.1  522.83      1  2019
# 1         Cash     9.6   76.40      3  2019
# 2  Credit card     7.4  324.31      3  2019
# 3      Ewallet     8.4  465.76      1  2019
# ...

# %%
df['Year'].unique()
# Out:
# array([2019])

# %% [markdown]
# ## Renaming Columns

# %%
df.rename(columns={'Total':'Revenue'}, inplace=True)
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Sales      Date   Time  Payment  \
# 0       Health and beauty       74.69      7  1/5/2019  13:08  Ewallet
# 1  Electronic accessories       15.28      5  3/8/2019  10:29     Cash
#
#    Rating  Revenue  Month  Year
# 0     9.1   522.83      1  2019
# 1     9.6    76.40      3  2019

# %%
df.rename(columns={'Quantity':"Sales"}, inplace=True)
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Sales      Date   Time  Payment  \
# 0       Health and beauty       74.69      7  1/5/2019  13:08  Ewallet
# 1  Electronic accessories       15.28      5  3/8/2019  10:29     Cash
#
#    Rating  Revenue  Month  Year
# 0     9.1   522.83      1  2019
# 1     9.6    76.40      3  2019

# %% [markdown]
# ## Data Analysis
# ##### 1.A) Analyze the performance of sales and revenue at the city and branch level ( 5 marks)

# %%
sales_revenue_city_branch_total = df.groupby(['City', 'Branch'])[['Revenue', 'Sales']].sum().reset_index()
sales_revenue_city_branch_total
# Out:
#         City Branch   Revenue  Sales
# 0   Mandalay      A  34130.09    637
# 1   Mandalay      B  37215.93    664
# 2   Mandalay      C  29794.62    519
# 3  Naypyitaw      A  35985.64    648
# 4  Naypyitaw      B  35157.75    604
# 5  Naypyitaw      C  34160.14    579
# 6     Yangon      A  33647.27    598
# 7     Yangon      B  35193.51    631
# 8     Yangon      C  32302.43    630

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(sales_revenue_city_branch_total['City'], sales_revenue_city_branch_total['Revenue'], label='Revenue', alpha=0.7)
ax.bar(sales_revenue_city_branch_total['City'], sales_revenue_city_branch_total['Sales'], label='Sales', alpha=0.7)
ax.set_xlabel('City/Branch')
ax.set_ylabel('Amount')
ax.set_title('Sales and Revenue by City/Branch')
ax.legend()
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# ##### 1.B) What is the average price of an item sold at each branch of the city (10 marks)

# %%
average_price_per_branch =round(df.groupby(['City', 'Branch'])['Unit price'].mean(),2).reset_index()
average_price_per_branch
# Out:
#         City Branch  Unit price
# 0   Mandalay      A       53.35
# 1   Mandalay      B       56.13
# 2   Mandalay      C       57.96
# 3  Naypyitaw      A       54.12
# 4  Naypyitaw      B       57.79
# 5  Naypyitaw      C       57.94
# 6     Yangon      A       55.64
# 7     Yangon      B       56.01
# 8     Yangon      C       52.68

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(average_price_per_branch['Branch'], average_price_per_branch['Unit price'], color='skyblue', alpha=0.7)
ax.set_xlabel('Branch')
ax.set_ylabel('Average Unit Price')
ax.set_title('Average Unit Price per Branch')
plt.show()

# %% [markdown]
# ##### 1.C) Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method, and identify the focus areas to get better sales for April 2019. (15 marks)

# %%
monthly_sales = df.groupby(['Year', 'Month', 'Product line', 'Gender', 'Payment'])['Sales'].sum().reset_index()
monthly_sales
# Out:
#      Year  Month            Product line  Gender      Payment  Sales
# 0    2019      1  Electronic accessories  Female         Cash     52
# 1    2019      1  Electronic accessories  Female  Credit card     54
# 2    2019      1  Electronic accessories  Female      Ewallet     43
# 3    2019      1  Electronic accessories    Male         Cash     62
# 4    2019      1  Electronic accessories    Male  Credit card     43
# ..    ...    ...                     ...     ...          ...    ...
# 103  2019      3       Sports and travel  Female  Credit card     52
# 104  2019      3       Sports and travel  Female      Ewallet     53
# 105  2019      3       Sports and travel    Male         Cash     36
# 106  2019      3       Sports and travel    Male  Credit card     60
# 107  2019      3       Sports and travel    Male      Ewallet     86
#
# [108 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Month', y='Sales', hue='Payment', data=monthly_sales, ci=None)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales by Payment Method')
plt.show()
# Out:
# C:\Users\anand\AppData\Local\Temp\ipykernel_2100\351346402.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Month', y='Sales', hue='Payment', data=monthly_sales, ci=None)

# %% [markdown]
# ##### This is related to 1.A where i took Unit Price inplace of Revenue

# %%
sales_revenue_city_branch = df.groupby(['City', 'Branch'])[['Unit price', 'Sales']].sum()
sales_revenue_city_branch
# Out:
#                   Unit price  Sales
# City      Branch
# Mandalay  A          6349.11    637
#           B          6623.73    664
#           C          5506.04    519
# Naypyitaw A          5953.55    648
#           B          6298.64    604
#           C          6315.57    579
# Yangon    A          6342.88    598
#           B          6329.25    631
#           C          5953.36    630

# %% [markdown]
# ## Conclusion:
# ##### The analysis highlights variations in sales and revenue performance across branches within Mandalay, Naypyitaw, and Yangon, indicating potential areas for targeted strategies. The average unit price of items sold varies by branch, suggesting differences in product mix or pricing strategies. Month over Month analysis reveals significant variations in sales and revenue by product line, gender, and payment method, guiding tailored marketing and sales strategies. To improve sales in April 2019, focus on high-performing product lines, targeted marketing by gender, and promoting preferred payment methods for enhanced performance.
